# %% [markdown]
# <a href="https://colab.research.google.com/github/samkamau81/Baini/blob/main/Speech_To_Text.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Baini
# ---
# #### ***swahili - to Uncover***
# #### By Samuel Waweru
#
# #### **Problem**
#
#
# #### **Solution**
# This App converts English Speech to Swahili Text using AI (Speech-to-Text Service)

# %%
import requests

# %% [markdown]
# #### Data Collection and Preping

# %% [markdown]
# #### Speech-to-Text Model

# %% [markdown]
# #### Text-to-Text Translation Model

# %% [markdown]
# Text-to-Text Translation Model is a type of natural language processing model used for translating text from one language to another.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
API_TOKEN = "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"
API_URL = "https://api-inference.huggingface.co/models/Helsinki-NLP/opus-mt-en-swc"
headers = {"Authorization": f"Bearer {API_TOKEN}"}

def query(payload):
	response = requests.post(API_URL, headers=headers, json=payload)
	return response.json()

# %%
def translate(input_text):
    translated_text = query({
        "inputs": input_text,
    })
    if translated_text:
        # Extract the translation text from the first dictionary in the list
        translation = translated_text[0].get("translation_text", "Translation not found")
        print(translation)
    else:
        print("No translation found")

# Example usage
translate("My name is Wolfgang and I live in Berlin")
# Out:
# Jina langu ni Wolfgang na ninaishi Berlin

# %% [markdown]
# #### Integration
